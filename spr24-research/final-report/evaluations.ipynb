# %%
#@title Import dependencies
import pandas as pd
from string import punctuation
import re
import numpy as np
import tensorflow as tf
import os
import time
import random

import matplotlib.pyplot as plt
# %matplotlib inline

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

from sklearn.model_selection import train_test_split

import unicodedata
import io
import pickle

# %%
NO_ATTN_PKLPATH = "/content/no-attn-translations.pkl"
BAH_ATTN_PKLPATH = "/content/bahdanau-attn-translations.pkl"
LUO_ATTN_PKLPATH = "/content/luong-attn-translations.pkl"

# %%
with open(NO_ATTN_PKLPATH, 'rb') as file:
    # Call load method to deserialze
    NO_ATTN_TRANSLATIONS = pickle.load(file)

with open(BAH_ATTN_PKLPATH, 'rb') as file:
    # Call load method to deserialze
    BAH_ATTN_TRANSLATIONS = pickle.load(file)

with open(LUO_ATTN_PKLPATH, 'rb') as file:
    # Call load method to deserialze
    LUO_ATTN_TRANSLATIONS = pickle.load(file)

# %%
NO_ATTN_TRANSLATIONS.head()
# Out:
#                                   Tokenized Original  \
# 0                                  no pueden <unk> .
# 1  el hombre mayor vivia en el apartamento de tre...
# 2              el me miro fijamente y no dijo nada .
# 3                         deberias decir la verdad .
# 4                           ¿ necesitas mas dinero ?
#
#                                         Reference  \
# 0                           You can't blame them.
# 1  The old man lived in the three-room apartment.
# 2               He stared at me and said nothing.
# 3                      You should tell the truth.
# 4                         Do you need more money?
#
#                                        Translation Precision  Recall      F1
# 0                                i'm not allowed .    0.4985  0.4664  0.4819
# 1            the boy lived in three with his car .    0.6373  0.6067  0.6217
# 2  he did his surprise , and i didn't understand .    0.4676  0.5170  0.4911
# ...

# %%
BAH_ATTN_TRANSLATIONS.head()
# Out:
#                                   Tokenized Original  \
# 0                               No pueden culparlos.
# 1  El hombre mayor vivía en el apartamento de tre...
# 2               Él me miró fijamente y no dijo nada.
# 3                          Deberías decir la verdad.
# 4                             ¿Necesitás más dinero?
#
#                                         Reference  \
# 0                           You can't blame them.
# 1  The old man lived in the three-room apartment.
# 2               He stared at me and said nothing.
# 3                      You should tell the truth.
# 4                         Do you need more money?
#
#                               Translation Precision  Recall      F1
# 0                     they can't stand it    0.5843  0.5573  0.5705
# 1  the older girl lived in three of the u    0.5165  0.4912  0.5035
# 2      he looked at me and not to nothing    0.5917  0.6048  0.5982
# ...

# %%
LUO_ATTN_TRANSLATIONS.head()
# Out:
#                                   Tokenized Original  \
# 0                                  no pueden <unk> .
# 1  el hombre mayor vivia en el apartamento de tre...
# 2              el me miro fijamente y no dijo nada .
# 3                         deberias decir la verdad .
# 4                           ¿ necesitas mas dinero ?
#
#                                         Reference  \
# 0                           You can't blame them.
# 1  The old man lived in the three-room apartment.
# 2               He stared at me and said nothing.
# 3                      You should tell the truth.
# 4                         Do you need more money?
#
#                                          Translation Precision  Recall      F1
# 0                               they can't fool us .    0.6931  0.6931  0.6931
# 1  the oldest used to live in the arm of the labo...    0.5362  0.5321  0.5341
# 2          he looked at me and didn't say anything .    0.8124  0.8808  0.8452
# ...

# %%
sum(NO_ATTN_TRANSLATIONS["Precision"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-ace316b0354a> in <cell line: 1>()
# ----> 1 sum(NO_ATTN_TRANSLATIONS["Precision"][1])
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print(f"=====\tavg precision\t=====")

sum1, sum2, sum3 = 0, 0, 0
for i in range(100):
    sum1+=float(NO_ATTN_TRANSLATIONS["Precision"][i])
    sum2+=float(BAH_ATTN_TRANSLATIONS["Precision"][i])
    sum3+=float(LUO_ATTN_TRANSLATIONS["Precision"][i])
avgp1, avgp2, avgp3 = sum1/100, sum2/100, sum3/100

print(f"for no attn   : {avgp1}")
print(f"for bah. attn : {avgp2}")
print(f"for luo. attn : {avgp3}")
# Out:
# =====	avg precision	=====
# for no attn   : 0.726187
# for bah. attn : 0.7099899999999998
# for luo. attn : 0.7902760000000001

# %%
print(f"=====\tavg recall\t=====")

sum1, sum2, sum3 = 0, 0, 0
for i in range(100):
    sum1+=float(NO_ATTN_TRANSLATIONS["Recall"][i])
    sum2+=float(BAH_ATTN_TRANSLATIONS["Recall"][i])
    sum3+=float(LUO_ATTN_TRANSLATIONS["Recall"][i])
avgp1, avgp2, avgp3 = sum1/100, sum2/100, sum3/100

print(f"for no attn   : {avgp1}")
print(f"for bah. attn : {avgp2}")
print(f"for luo. attn : {avgp3}")
# Out:
# =====	avg recall	=====
# for no attn   : 0.7196959999999999
# for bah. attn : 0.6759390000000002
# for luo. attn : 0.7916350000000001

# %%
print(f"=====\tavg F1\t=====")

sum1, sum2, sum3 = 0, 0, 0
for i in range(100):
    sum1+=float(NO_ATTN_TRANSLATIONS["F1"][i])
    sum2+=float(BAH_ATTN_TRANSLATIONS["F1"][i])
    sum3+=float(LUO_ATTN_TRANSLATIONS["F1"][i])
avgp1, avgp2, avgp3 = sum1/100, sum2/100, sum3/100

print(f"for no attn   : {avgp1}")
print(f"for bah. attn : {avgp2}")
print(f"for luo. attn : {avgp3}")
# Out:
# =====	avg F1	=====
# for no attn   : 0.7222320000000001
# for bah. attn : 0.691875
# for luo. attn : 0.790427
